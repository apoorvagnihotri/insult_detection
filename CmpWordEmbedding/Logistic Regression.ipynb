# %% [markdown]
# # This notebook compares the Accuracy and AUC socre on Logistic Regression classifier using  different word embedding methods.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from gensim.models import Word2Vec
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from IPython.display import display, Markdown, Latex
import spacy
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
class word2vec:         
    def transform(self,text):
        l = [[j.lower() for j in word_tokenize(i)] for i in text]
        model = Word2Vec(l,size=300, \
            window=7, \
            min_count=0,\
            workers=1)
        model.train(l, total_examples=len(l), epochs=10)
        updated_vector = []
        for i in l:
            p=0
            for j in i:
                p+=model.wv[j]
            updated_vector.append(p)
        return(updated_vector)
    def transformSpacy(self,text):
        model = spacy.load("en_core_web_md")
      #  text2vec = [model(i).vector for i in text['comment'].fillna(" ").tolist()]
        #dimmension of vector = 300x1
        text2vec = [model(i).vector for i in text]
        return text2vec

# %%
#parameters:
#size ->  dimensionality of the word vector
#window -> the window size(maximum distance between the current and predicted word within a sentence)
#min_count -> ignores all words with total frequency lower than this
#workers -> faster training with multicore machine

df_train = pd.read_csv('../cleaned_dataset.csv')
df_test = pd.read_csv('../Preprocessed Data//cleaned_dataset_train.csv')
#df = pd.read_csv('../cleaned_dataset.csv')
#print(df_train["comment"].fillna(" ").tolist());

df_test=df_test.drop(df_test.index[[114,153,1944]]).reset_index(drop=True)

# %% [markdown]
# # Word embedding used - Contineous bag of words

# %%
df_train = df_train.fillna('')
df_test = df_test.fillna('')
X_train = df_train["comment"]
Y_train = df_train["insult"].tolist()

X_test = df_test["comment"]
Y_test = df_test["insult"].tolist()

# %%
vectorizer = CountVectorizer()
vectorizer.fit(X_train)

X_train = vectorizer.transform(X_train)
X_test = vectorizer.transform(X_test)

# %%
clf = LogisticRegression(C = 3, class_weight="balanced",warm_start=True)
clf.fit(X_train,Y_train)
# Out:
# LogisticRegression(C=3, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=True)

# %%
predictions=clf.predict_proba(X_test)

final = []
for prediction in predictions:
    final.append(prediction[1])
    
acc = 0
aoc = metrics.roc_auc_score(Y_test,final)
data = "**Accuracy** : " + str(acc) + "<br>" + "**AUC Score** : " + str(aoc) 
display(Markdown(data))
# Out:
# **Accuracy** : 0<br>**AUC Score** : 0.9986976970077179

# %% [markdown]
# # Word embedding used - TF-IDF

# %%
df_train = df_train.fillna('')
df_test = df_test.fillna('')
X_train = df_train["comment"]
Y_train = df_train["insult"].tolist()

X_test = df_test["comment"]
Y_test = df_test["insult"].tolist()

# %%
vectorizer = TfidfVectorizer()
vectorizer.fit(X_train)

X_train = vectorizer.transform(X_train)
X_test = vectorizer.transform(X_test)

# %%
print (type(X_train),type(Y_train))
# Out:
# <class 'scipy.sparse.csr.csr_matrix'> <class 'list'>

# %%
clf = LogisticRegression(C = 3, class_weight="balanced",warm_start=True)
clf.fit(X_train,Y_train)
# Out:
# LogisticRegression(C=3, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=True)

# %%
predictions=clf.predict_proba(X_test)

final = []
for prediction in predictions:
    final.append(prediction[1])
    
acc = 0
aoc = metrics.roc_auc_score(Y_test,final)
data = "**Accuracy** : " + str(acc) + "<br>" + "**AUC Score** : " + str(aoc) 
display(Markdown(data))
# Out:
# **Accuracy** : 0<br>**AUC Score** : 0.9891929444667033

# %% [markdown]
# # Word embedding used - Word2vec(Gensim)

# %%
df_train = df_train.fillna('')
df_test = df_test.fillna('')
X_train = df_train["comment"]
Y_train = df_train["insult"].tolist()

X_test = df_test["comment"]
Y_test = df_test["insult"].tolist()

# %%
vectorizer = word2vec()
X_train=vectorizer.transform(X_train)
X_test=vectorizer.transform(X_test)

# %%
clf = LogisticRegression(C = 3, class_weight="balanced",warm_start=True)
clf.fit(X_train,Y_train)
# Out:
# LogisticRegression(C=3, class_weight='balanced', dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=True)

# %%
predictions=clf.predict_proba(X_test)

final = []
for prediction in predictions:
    final.append(prediction[1])
    
acc = 0
aoc = metrics.roc_auc_score(Y_test,final)
data = "**Accuracy** : " + str(acc) + "<br>" + "**AUC Score** : " + str(aoc) 
display(Markdown(data))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-143-f3881b9151a9> in <module>()
# ----> 1 predictions=clf.predict_proba(X_test)
#       2
#       3 final = []
#       4 for prediction in predictions:
#       5     final.append(prediction[1])
#
# ~/.local/lib/python3.5/site-packages/sklearn/linear_model/logistic.py in predict_proba(self, X)
#    1338         calculate_ovr = self.coef_.shape[0] == 1 or self.multi_class == "ovr"
#    1339         if calculate_ovr:
# -> 1340             return super(LogisticRegression, self)._predict_proba_lr(X)
#    1341         else:
#    1342             return softmax(self.decision_function(X), copy=False)
#
# ~/.local/lib/python3.5/site-packages/sklearn/linear_model/base.py in _predict_proba_lr(self, X)
#     336         multiclass is handled by normalizing that over all classes.
#     337         """
# --> 338         prob = self.decision_function(X)
#     339         prob *= -1
#     340         np.exp(prob, prob)
#
# ~/.local/lib/python3.5/site-packages/sklearn/linear_model/base.py in decision_function(self, X)
#     298                                  "yet" % {'name': type(self).__name__})
#     299
# --> 300         X = check_array(X, accept_sparse='csr')
#     301
#     302         n_features = self.coef_.shape[1]
#
# ~/.local/lib/python3.5/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     439                     "Reshape your data either using array.reshape(-1, 1) if "
#     440                     "your data has a single feature or array.reshape(1, -1) "
# --> 441                     "if it contains a single sample.".format(array))
#     442             array = np.atleast_2d(array)
#     443             # To ensure that array flags are maintained
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[array([ 2.1320491e+00,  2.3752143e+00, -7.8668797e-01,  8.8871038e-01,
#         1.8910249e+00,  6.1280715e-01, -2.7012959e+00, -1.3981383e+00,
#        -2.5347571e+00, -1.6379753e-01, -2.3247874e+00,  3.7491415e+00,
#         8.2080173e-01,  1.9123616e+00, -1.9669726e+00, -3.6921251e-01,
#         1.4297228e+00,  1.4781778e+00, -3.5227652e+00,  8.2907772e-01,
#         9.4003344e-01,  1.0751281e+00,  2.7282462e+00, -2.2093568e+00,
#        -3.9501131e-02, -2.5696115e+00, -8.6708176e-01, -1.5829028e+00,
#        -5.7871884e-01,  8.7803856e-02,  1.2088935e+00,  1.9622154e+00,
#         7.4651420e-02, -4.0767920e-01,  8.0323881e-01,  1.9814758e+00,
#        -1.1158792e+00,  1.7959747e+00,  6.7305505e-01,  3.1809864e+00,
#        -1.4158821e-01, -1.6363920e+00, -7.2728592e-01, -1.3294070e+00,
#         2.9951677e-02,  8.3522457e-01, -4.0392418e+00,  1.0316290e+00,
#         1.3967638e+00,  3.3599455e+00,  6.9919395e-01,  7.2408766e-01,
#        -1.3126551e+00, -1.6622293e+00, -2.4680430e-01, -2.8208883e+00,
#        -3.5397215e+00, -2.8394482e-01,  1.4700857e+00,  2.2831101e+00,
#        -3.2521884e+00,  2.1615431e+00, -5.4238099e-01, -1.8672020e+00,
#         1.6014007e+00, -3.8945293e-01,  5.3760016e-01,  7.0155188e-02,
#         1.2329313e+00, -8.9950448e-01,  1.2708060e+00,  6.1929691e-01,
#         2.2044907e+00, -1.8589047e+00, -4.2537487e-01, -1.3900449e+00,
#        -1.1305913e+00,  3.7081134e-01, -1.3359728e+00,  2.1911044e+00,
#         2.1008353e+00, -2.4452882e+00,  9.9889278e-01, -2.0946486e+00,
#         9.7937137e-01, -3.8523951e-01,  1.3442086e+00, -1.1932583e+00,
#         3.6503100e-01, -3.7466639e-01,  2.1152505e-01, -8.8609773e-01,
#          5.6581297 ,  -4.4064517 ,   8.627594  ,  -6.3192677 ,
#         -7.0745277 ,  34.513317  ,   5.6429305 ,  -5.6435714 ,
#         13.977588  ,  -6.691183  ,   8.159082  , -22.598148  ,
#         15.724813  ,   3.0348299 ,  22.955244  ,   4.788044  ,
#         18.585236  ,  18.237152  ,  -1.8013315 ,   7.964455  ,
#          6.1445527 ,  -6.3636065 ,  -6.485971  ,   5.496199  ,
#         -0.8742217 ,  19.383064  ,   6.426745  ,  -8.6642    ,
#         14.508084  ,  -4.2460423 , -10.661339  ,  15.6754055 ,
#        -16.966839  ,  -5.8737316 ,  -3.377657  , -34.97538   ,
#          2.122007  ,  -5.1654797 ,  18.803564  ,  -5.098695  ,
#        -14.065482  , -10.198389  , -10.129887  ,  -1.7596622 ,
#         -4.270035  ,   7.443904  ,   5.747171  ,   1.8003829 ,
#         -8.807849  , -10.516121  ,  -0.3111835 ,   2.1392078 ,
#         -8.840698  ,   5.0616035 ,  25.253012  ,  -1.5402694 ,
#          8.082147  ,  -1.1454213 ,   6.5494614 ,   1.8767774 ,
#          7.358071  ,  -7.928794  ,   7.0315776 ,   7.9173    ,
#         17.74232   ,  22.031927  ,  13.489089  , -17.155472  ,
#        -12.544865  ,  -7.6650558 ,  -8.235935  ,  -4.9807267 ,
#          7.4815784 , -18.669573  , -20.32417   ,  -3.335257  ,
#         -1.8214763 , -10.868979  ,  30.566725  ,  11.981405  ,
#        -27.990173  ,   4.9955044 ,  -6.0556183 ,   4.008055  ,
#        -30.181824  ,  24.207438  ,   1.2046466 ,  -5.8244576 ,
#         10.149443  ,  13.598796  ,  -5.2492504 ,  -6.4043117 ,
#         -3.9867725 ,   5.3579307 , -11.521772  ,  -7.3634343 ,
#        -11.179863  ,  30.401604  ,   7.308155  ,   5.402758  ,
#         -5.8380933 ,  -9.642205  ,  13.953608  ,  12.1687    ,
#         23.487831  ,   4.5464816 ,   6.356125  ,   0.7233083 ,
#         -3.1808074 ,  19.979372  , -10.00261   ,   9.216857  ,
#        -20.88065   ,  15.039955  ,   5.918304  ,   8.352308  ,
#        -10.653034  , -15.673773  , -13.587646  ,  -2.150216  ,
#         -5.0246253 ,   7.539858  ,  19.029867  ,  -2.439208  ,
#          5.0810194 ,  -1.1829771 , -21.623167  ,  -4.2432256 ],
#       dtype=float32)].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %% [markdown]
# # Word embedding used - Word2vec(spacy)

# %%
df_train = df_train.fillna('')
df_test = df_test.fillna('')
X_train = df_train["comment"]
Y_train = df_train["insult"].tolist()

X_test = df_test["comment"]
Y_test = df_test["insult"].tolist()

# %%
vectorizer = word2vec()
X_train=vectorizer.transformSpacy(X_train)
X_test=vectorizer.transformSpacy(X_test)

# %%
print (type(X_train),type(Y_train))

# %%
clf = LogisticRegression(C = 3, class_weight="balanced",warm_start=True)
clf.fit(X_train,Y_train)

# %%
predictions=clf.predict_proba(X_test)

final = []
for prediction in predictions:
    final.append(prediction[1])
    
acc = 0
aoc = metrics.roc_auc_score(Y_test,final)
data = "**Accuracy** : " + str(acc) + "<br>" + "**AUC Score** : " + str(aoc) 
display(Markdown(data))
