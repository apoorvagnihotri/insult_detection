# %%
import pandas as pd
import numpy as np
import sklearn
import nltk
import re

def cleanhtml(raw_html):
  cleanr = re.compile('<.*?>')
  cleantext = re.sub(cleanr, '', raw_html)
  return cleantext

# %%
df = pd.read_csv('/Users/ritikdutta/Downloads/all/train.csv')
print(df.iloc[1]['Comment'])
print(cleanhtml(df.iloc[1]['Comment']))
# Out:
# "i really don't understand your point.\xa0 It seems that you are mixing apples and oranges."
# "i really don't understand your point.\xa0 It seems that you are mixing apples and oranges."

# %%
for i in range(df.shape[0]):
    df.set_value(i, 'Comment', cleanhtml(df.iloc[i]['Comment']))
# Out:
# /Users/ritikdutta/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead

# %%
positive = df[df['Insult'] == 1]
negative = df[df['Insult'] == 0]

# %%
negative
# Out:
#       Insult             Date  \
# 1          0  20120528192215Z
# 2          0              NaN
# 3          0              NaN
# 4          0  20120619094753Z
# 5          0  20120620171226Z
# 6          0  20120503012628Z
# 10         0  20120620015140Z
# 11         0  20120530044519Z
# 12         0              NaN
# 13         0              NaN
# 14         0              NaN
# 17         0              NaN
# 20         0  20120612051612Z
# 21         0  20120611234235Z
# 22         0  20120502215304Z
# 23         0  20120503031721Z
# 24         0              NaN
# 25         0  20120612144331Z
# 26         0  20120529025329Z
# 27         0  20120612052926Z
# 28         0  20120528193950Z
# 29         0  20120529230121Z
# 30         0  20120611201838Z
# 31         0  20120529115214Z
# 32         0              NaN
# 33         0  20120620055647Z
# 35         0  20120620011710Z
# 36         0  20120530111709Z
# 39         0  20120619094846Z
# 40         0  20120609175446Z
# ...
